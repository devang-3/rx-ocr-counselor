# %%
# !pip install pytesseract pillow
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pytesseract
from pytesseract import Output
import cv2
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,30)

# %%
img = cv2.imread("/teamspace/studios/this_studio/page_image/2nPPipXy.jpg")
plt.imshow(img)

# %%
import pytesseract
from PIL import Image

# ONLY for Windows users: point to the installed tesseract.exe
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Open an image and convert to string
img = Image.open('/teamspace/studios/this_studio/page_image/2nPPipXy.jpg')
text = pytesseract.image_to_string(img)

print(text)
# Out:
# Allergies:
#
# History and complaints:
#
# Examination:
#
# Provisional/Final Diagnosis:
#
# Nutritional Screening
#
# Advice:
# (Lifestyle / Rehab / Diet)
#
# Findings:
# Chest clear
#
# Abdomen- Fecolith Palpable
# Throat normal
#
# Pallor
#
# Significant history:
# Xray abdomen suggestive of fecal
#
# loading. Mantoux -negativagt#lers:
# chest -normal
#
# Diagnosis:
# Constipation
# Acuté Respiratory Tract Infection
#
# Investigations:
#
# Instructions:
#
# *  Nebulise'with Levosalbutamol(0.63) plus Bu
#
# Medici:
# 1.
#
# a
#
# a8
#
# Syrup Allegra:
# Fexorenanine(30 Mc)
#
# Smi
#
# . Syru
# Amaroxo. HyorocH.orine(30 ma) + GuaipHenesin(S0 ma)
# + Tenpurauine Sucprate(1.25 ma)+ Mentor (0.5mc)
#
# 5 mi
#
# - Twice a day X 4 Days
# p Ambrolite S:
#
# - Twice a day X 3 Days
#
# . Suspension Azithral 200:
#
# AzrmHromycin(200 ma)
# 3.5 ml - Once a day
# Till 21/2/20
#
# . Suspension Looz:
#
# Lacrutose(10 cu)
# 10 ml - Once a day X 1 Month
#
# . Sachet Pegura-17g:
#
# ...
